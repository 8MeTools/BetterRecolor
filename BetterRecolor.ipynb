# %% [markdown]
# <a href="https://colab.research.google.com/github/8MeTools/BetterRecolor/blob/main/BetterRecolor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["BTRC_PATH"] = "/content/BetterRecolor"
os.environ["GITHUB_REPO_URL"] = "https://github.com/8MeTools/BetterRecolor"
os.environ["GITHUB_BRANCH_NAME"] = "feat/pack-guide"

# %%
# Confirm env values
# !echo $BTRC_PATH
# !echo $GITHUB_REPO_URL
# !echo $GITHUB_BRANCH_NAME

# %%
# %cd /content
# %rm -rf {os.environ["BTRC_PATH"]}
# Cloning BetterRecolor repository from GitHub and navigating into it
# !git clone -b {os.environ["GITHUB_BRANCH_NAME"]} --depth 1 {os.environ["GITHUB_REPO_URL"]}
# %cd {os.environ["BTRC_PATH"]}
# Removing unnecessary files and directories, then listing the remaining contents
# %rm -rf docs/*.md scripts/ tests/ .github/ .gitignore pyproject.toml requirements-dev.txt
# %ls $BTRC_PATH -la

# %%
# Installing dependencies from requirements.txt and confirming setup completion
# !pip install -r requirements.txt
print("✅ Setup complete! Open color_config.json to edit.")

# %%
# Optional CLI arguments:
#   --lang [ja|en]  # Default: ja
#     ja = Japanese, en = English
#
#   --yes (-y)      # Default: False
#     Automatically answer "yes" to all prompts
#
# Example:
# !python main.py --lang ja --yes

# !python main.py --lang ja --yes

# %%
# Compressing the Output directory into a zip file named Output.zip
# !zip -rq Output.zip Output

# Download
from google.colab import files
files.download("Output.zip")
